# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:brown;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Web Scraping of ecommerce website
# </p>
# </div>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
#
# <div style="font-family:Georgia;background-color:'#DEB887'; padding:30px; font-size:17px">
#
# <b>Project Objective - </b> The objective of this project is to extract the Product name, Price and Ratings of Realme Poco M4 Mobile from Flipkart website.<br>

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:80%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Step 1 - Importing required libaries</p>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Note:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# * Requests library is used to send HTTP requests to a specified URL.
# * Beautiful Soup is used to pull out HTML files.

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:80%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Step 2 - Getting response</p>

# %%
url='https://www.flipkart.com/search?q=realme+poco+m4+pro&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_11_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_11_na_na_na&as-pos=2&as-type=RECENT&suggestionId=realme+poco+m4+pro%7CMobiles&requestId=80c5cdf1-8907-427d-8ec7-e6078ff99817&as-searchtext=realme%20poco'
response=requests.get(url)
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Note:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
#
# Response 200 implies that request connection to the website is successful.

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:80%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Step 3 - Getting the html content</p>

# %%
htmlcontent=response.text
print(htmlcontent)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.
# ...

# %%
soup=BeautifulSoup(htmlcontent,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:80%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Step 4 - To pull the data from html codes efficiently </p>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:left">
#
# <h3 align="left"><font color='#DEB887'>💡 Note:</font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# Prettify helps to extract the html content in an organized manner.

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:80%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Step 5 - Taking out the necessary information  </p>

# %%
website_content=soup.find_all('a',href=True,class_='_1fQZEK')
print(len(website_content))
for a in website_content:
    name=a.find('div',class_='_4rR01T')
    price=a.find('div',attrs={'class': '_30jeq3 _1_WHN1'})
    rating=a.find('div',attrs={'class': '_3LWZlK'})
    print(name)
# Out:
# 24
# <div class="_4rR01T">POCO M4 Pro (Yellow, 128 GB)</div>
# <div class="_4rR01T">POCO M4 Pro (Power Black, 128 GB)</div>
# <div class="_4rR01T">POCO M4 Pro (Power Black, 128 GB)</div>
# <div class="_4rR01T">POCO M4 Pro (Yellow, 128 GB)</div>
# <div class="_4rR01T">POCO M4 Pro (Yellow, 64 GB)</div>
# <div class="_4rR01T">POCO M4 Pro (Cool Blue, 128 GB)</div>
# <div class="_4rR01T">POCO M4 Pro 5G (Yellow, 128 GB)</div>
# <div class="_4rR01T">POCO M4 Pro 5G (Cool Blue, 128 GB)</div>
# <div class="_4rR01T">POCO M4 Pro 5G (Cool Blue, 128 GB)</div>
# <div class="_4rR01T">POCO M4 Pro 5G (Yellow, 64 GB)</div>
# <div class="_4rR01T">POCO M4 Pro 5G (Yellow, 128 GB)</div>
# <div class="_4rR01T">POCO X5 Pro 5G (Astral Black, 256 GB)</div>
# <div class="_4rR01T">POCO M3 Pro 5G (Yellow, 128 GB)</div>
# <div class="_4rR01T">POCO X5 Pro 5G (Yellow, 256 GB)</div>
# <div class="_4rR01T">POCO X4 Pro 5G (Yellow, 128 GB)</div>
# <div class="_4rR01T">POCO X5 Pro 5G (Horizon Blue, 256 GB)</div>
# ...

# %%
products=[] # List to store the product name
prices=[] # List to store the product price
ratings=[] # List to store the product rating

# %%
website_content=soup.find_all('a',href=True,class_='_1fQZEK')
for a in website_content:
    name=a.find('div',class_='_4rR01T')
    price=a.find('div',attrs={'class': '_30jeq3 _1_WHN1'})
    rating=a.find('div',attrs={'class': '_3LWZlK'})
    products.append(name.text)
    prices.append(price.text)
    ratings.append(rating.text)

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:80%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Step 6 - Converting it into dataframe  </p>

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Product name':products,'Price':prices,'Rating':ratings})
print(df)
# Out:
#                              Product name           Price Rating
# 0       POCO M4 Pro (Power Black, 128 GB)  ₹13,999₹13,999    4.2
# 1            POCO M4 Pro (Yellow, 128 GB)  ₹13,999₹13,999    4.2
# 2         POCO M4 Pro (Cool Blue, 128 GB)  ₹13,999₹13,999    4.2
# 3       POCO M4 Pro (Power Black, 128 GB)  ₹16,499₹16,499    4.3
# 4            POCO M4 Pro (Yellow, 128 GB)  ₹16,499₹16,499    4.3
# 5             POCO M4 Pro (Yellow, 64 GB)  ₹14,999₹14,999    4.3
# 6         POCO M4 Pro 5G (Yellow, 128 GB)  ₹15,999₹15,999    4.2
# 7      POCO M4 Pro 5G (Cool Blue, 128 GB)  ₹16,999₹16,999    4.2
# 8      POCO M4 Pro 5G (Cool Blue, 128 GB)  ₹15,999₹15,999    4.2
# 9          POCO M4 Pro 5G (Yellow, 64 GB)  ₹14,999₹14,999    4.3
# 10        POCO M4 Pro 5G (Yellow, 128 GB)  ₹16,999₹16,999    4.2
# 11  POCO X5 Pro 5G (Astral Black, 256 GB)  ₹23,999₹23,999    4.3
# 12        POCO X5 Pro 5G (Yellow, 256 GB)  ₹23,999₹23,999    4.3
# ...

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: purple; font-size:80%; text-align:left">
# <p style="font-family:Georgia; font-weight:bold; letter-spacing: 2px; color:white; font-size:200%; text-align:center;padding: 0px;"> Step 7 - Converting it into csv file  </p>

# %%
df.to_csv('ProductList.csv',index=False,encoding='utf-8-sig')
